# %%
import pandas as pd
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
from time import time

# %%
df = pd.read_pickle('dataset.pkl')
print(len(df))
total_hours = len(df['id_hour'].unique())
print(len(df) / total_hours)
# create training, test, validation set
print('Creating training, validation, test set')
train_size = int(total_hours*0.7)
valid_size = int(total_hours*0.15)
test_size = int(total_hours*0.15)
df_train = df[df['id_hour'] < train_size]
df_valid = df[(df['id_hour'] >= train_size) & (df['id_hour'] < (train_size+valid_size))]
df_test = df[(df['id_hour'] >= (train_size+valid_size))]
X_train, y_train = df_train.drop(['id_hour', 'net_rate'], axis=1), df_train['net_rate']
X_valid, y_valid = df_valid.drop(['id_hour', 'net_rate'], axis=1), df_valid['net_rate']
X_test, y_test = df_test.drop(['id_hour', 'net_rate'], axis=1), df_test['net_rate']
del df_train
del df_valid
del df_test
del df
# Out:
# 610032
# 71.0
# Creating training, validation, test set

# %%
t1 = time()
model = XGBRegressor(max_depth=7, n_estimators=500) #, min_child_weight=100, colsample_bytree=0.8, subsample=0.8, eta=0.3, seed=42)
model.fit(X_train, y_train, eval_metric="rmse", 
          eval_set=[(X_train, y_train), (X_valid, y_valid)], verbose=True, early_stopping_rounds = 10)
t2 = time()
print('Total of training time: ', t2-t1)
results = model.evals_result()
epochs = len(results['validation_0']['rmse'])
x_axis = range(0, epochs)
# plot log loss
plt.plot(x_axis, results['validation_0']['rmse'], label='Train')
plt.plot(x_axis, results['validation_1']['rmse'], label='Valid')
plt.legend()
plt.ylabel('RMSE')
plt.title('XGBoost RMSE')
plt.show()
# Out:
# [0]	validation_0-rmse:1.62971	validation_1-rmse:1.69361
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.57347	validation_1-rmse:1.6388
# [2]	validation_0-rmse:1.52131	validation_1-rmse:1.58677
# [3]	validation_0-rmse:1.47754	validation_1-rmse:1.54686
# [4]	validation_0-rmse:1.43842	validation_1-rmse:1.51164
# [5]	validation_0-rmse:1.40339	validation_1-rmse:1.47811
# [6]	validation_0-rmse:1.37371	validation_1-rmse:1.44877
# [7]	validation_0-rmse:1.3471	validation_1-rmse:1.42294
# [8]	validation_0-rmse:1.32424	validation_1-rmse:1.40131
# [9]	validation_0-rmse:1.30347	validation_1-rmse:1.38253
# [10]	validation_0-rmse:1.28432	validation_1-rmse:1.3654
# [11]	validation_0-rmse:1.26717	validation_1-rmse:1.3499
# [12]	validation_0-rmse:1.25145	validation_1-rmse:1.33573
# [13]	validation_0-rmse:1.23773	validation_1-rmse:1.32371
# [14]	validation_0-rmse:1.22602	validation_1-rmse:1.31246
# [15]	validation_0-rmse:1.21416	validation_1-rmse:1.30143
# [16]	validation_0-rmse:1.20149	validation_1-rmse:1.2909
# [17]	validation_0-rmse:1.19198	validation_1-rmse:1.28248
# [18]	validation_0-rmse:1.18202	validation_1-rmse:1.27411
# [19]	validation_0-rmse:1.17293	validation_1-rmse:1.26718
# [20]	validation_0-rmse:1.16466	validation_1-rmse:1.26016
# [21]	validation_0-rmse:1.15737	validation_1-rmse:1.2534
# [22]	validation_0-rmse:1.15035	validation_1-rmse:1.24795
# [23]	validation_0-rmse:1.14427	validation_1-rmse:1.24303
# [24]	validation_0-rmse:1.13802	validation_1-rmse:1.23843
# [25]	validation_0-rmse:1.13206	validation_1-rmse:1.23398
# [26]	validation_0-rmse:1.12686	validation_1-rmse:1.23077
# [27]	validation_0-rmse:1.12237	validation_1-rmse:1.22708
# [28]	validation_0-rmse:1.11781	validation_1-rmse:1.22412
# [29]	validation_0-rmse:1.11342	validation_1-rmse:1.22126
# [30]	validation_0-rmse:1.1097	validation_1-rmse:1.21875
# [31]	validation_0-rmse:1.1061	validation_1-rmse:1.21653
# [32]	validation_0-rmse:1.10271	validation_1-rmse:1.21445
# [33]	validation_0-rmse:1.09947	validation_1-rmse:1.21232
# [34]	validation_0-rmse:1.09681	validation_1-rmse:1.21101
# [35]	validation_0-rmse:1.09376	validation_1-rmse:1.20881
# [36]	validation_0-rmse:1.09152	validation_1-rmse:1.20715
# [37]	validation_0-rmse:1.08941	validation_1-rmse:1.20578
# [38]	validation_0-rmse:1.08684	validation_1-rmse:1.20441
# [39]	validation_0-rmse:1.08499	validation_1-rmse:1.20305
# [40]	validation_0-rmse:1.08288	validation_1-rmse:1.20213
# [41]	validation_0-rmse:1.08089	validation_1-rmse:1.20135
# [42]	validation_0-rmse:1.07901	validation_1-rmse:1.20016
# [43]	validation_0-rmse:1.07747	validation_1-rmse:1.1993
# [44]	validation_0-rmse:1.07554	validation_1-rmse:1.19873
# [45]	validation_0-rmse:1.07407	validation_1-rmse:1.19812
# [46]	validation_0-rmse:1.07227	validation_1-rmse:1.19733
# [47]	validation_0-rmse:1.07086	validation_1-rmse:1.1969
# [48]	validation_0-rmse:1.06982	validation_1-rmse:1.1964
# [49]	validation_0-rmse:1.06834	validation_1-rmse:1.19561
# [50]	validation_0-rmse:1.06716	validation_1-rmse:1.19514
# [51]	validation_0-rmse:1.0659	validation_1-rmse:1.19488
# [52]	validation_0-rmse:1.06489	validation_1-rmse:1.19453
# [53]	validation_0-rmse:1.06387	validation_1-rmse:1.19414
# [54]	validation_0-rmse:1.06281	validation_1-rmse:1.19384
# [55]	validation_0-rmse:1.06153	validation_1-rmse:1.19321
# [56]	validation_0-rmse:1.06074	validation_1-rmse:1.19288
# [57]	validation_0-rmse:1.05984	validation_1-rmse:1.19297
# [58]	validation_0-rmse:1.0594	validation_1-rmse:1.19273
# [59]	validation_0-rmse:1.05857	validation_1-rmse:1.19231
# [60]	validation_0-rmse:1.05749	validation_1-rmse:1.19219
# [61]	validation_0-rmse:1.05641	validation_1-rmse:1.19157
# [62]	validation_0-rmse:1.05531	validation_1-rmse:1.19127
# [63]	validation_0-rmse:1.05445	validation_1-rmse:1.19131
# [64]	validation_0-rmse:1.05399	validation_1-rmse:1.19108
# [65]	validation_0-rmse:1.05278	validation_1-rmse:1.19064
# [66]	validation_0-rmse:1.0516	validation_1-rmse:1.1906
# [67]	validation_0-rmse:1.0511	validation_1-rmse:1.19074
# [68]	validation_0-rmse:1.05039	validation_1-rmse:1.19059
# [69]	validation_0-rmse:1.04933	validation_1-rmse:1.19067
# [70]	validation_0-rmse:1.04889	validation_1-rmse:1.19051
# [71]	validation_0-rmse:1.04813	validation_1-rmse:1.1906
# [72]	validation_0-rmse:1.04702	validation_1-rmse:1.19056
# [73]	validation_0-rmse:1.04631	validation_1-rmse:1.19052
# [74]	validation_0-rmse:1.04515	validation_1-rmse:1.18993
# [75]	validation_0-rmse:1.04441	validation_1-rmse:1.18965
# [76]	validation_0-rmse:1.04344	validation_1-rmse:1.18936
# [77]	validation_0-rmse:1.04312	validation_1-rmse:1.18933
# [78]	validation_0-rmse:1.04221	validation_1-rmse:1.18916
# [79]	validation_0-rmse:1.0417	validation_1-rmse:1.18918
# [80]	validation_0-rmse:1.04066	validation_1-rmse:1.18927
# [81]	validation_0-rmse:1.04006	validation_1-rmse:1.18916
# [82]	validation_0-rmse:1.03926	validation_1-rmse:1.18897
# [83]	validation_0-rmse:1.03861	validation_1-rmse:1.18894
# [84]	validation_0-rmse:1.03803	validation_1-rmse:1.18871
# [85]	validation_0-rmse:1.03757	validation_1-rmse:1.18869
# [86]	validation_0-rmse:1.03659	validation_1-rmse:1.18859
# [87]	validation_0-rmse:1.03614	validation_1-rmse:1.18868
# [88]	validation_0-rmse:1.03518	validation_1-rmse:1.18805
# [89]	validation_0-rmse:1.03403	validation_1-rmse:1.18793
# [90]	validation_0-rmse:1.03316	validation_1-rmse:1.18785
# [91]	validation_0-rmse:1.03226	validation_1-rmse:1.18775
# [92]	validation_0-rmse:1.03154	validation_1-rmse:1.18765
# [93]	validation_0-rmse:1.03047	validation_1-rmse:1.1876
# [94]	validation_0-rmse:1.0301	validation_1-rmse:1.18764
# [95]	validation_0-rmse:1.02927	validation_1-rmse:1.18725
# [96]	validation_0-rmse:1.02822	validation_1-rmse:1.18731
# [97]	validation_0-rmse:1.02734	validation_1-rmse:1.18709
# [98]	validation_0-rmse:1.02712	validation_1-rmse:1.18712
# [99]	validation_0-rmse:1.02664	validation_1-rmse:1.18702
# [100]	validation_0-rmse:1.02571	validation_1-rmse:1.18686
# [101]	validation_0-rmse:1.02544	validation_1-rmse:1.18665
# [102]	validation_0-rmse:1.02447	validation_1-rmse:1.18669
# [103]	validation_0-rmse:1.02418	validation_1-rmse:1.18668
# [104]	validation_0-rmse:1.02353	validation_1-rmse:1.18647
# [105]	validation_0-rmse:1.02322	validation_1-rmse:1.18648
# [106]	validation_0-rmse:1.02256	validation_1-rmse:1.18643
# [107]	validation_0-rmse:1.02222	validation_1-rmse:1.18638
# [108]	validation_0-rmse:1.02114	validation_1-rmse:1.18633
# [109]	validation_0-rmse:1.02095	validation_1-rmse:1.18617
# [110]	validation_0-rmse:1.02075	validation_1-rmse:1.18647
# [111]	validation_0-rmse:1.02036	validation_1-rmse:1.18653
# [112]	validation_0-rmse:1.01996	validation_1-rmse:1.18642
# [113]	validation_0-rmse:1.01917	validation_1-rmse:1.18616
# [114]	validation_0-rmse:1.01853	validation_1-rmse:1.18609
# [115]	validation_0-rmse:1.01809	validation_1-rmse:1.186
# [116]	validation_0-rmse:1.01767	validation_1-rmse:1.186
# [117]	validation_0-rmse:1.01717	validation_1-rmse:1.18594
# [118]	validation_0-rmse:1.01631	validation_1-rmse:1.18594
# [119]	validation_0-rmse:1.01604	validation_1-rmse:1.18607
# [120]	validation_0-rmse:1.01543	validation_1-rmse:1.18617
# [121]	validation_0-rmse:1.01503	validation_1-rmse:1.18626
# [122]	validation_0-rmse:1.01428	validation_1-rmse:1.18616
# [123]	validation_0-rmse:1.01358	validation_1-rmse:1.18606
# [124]	validation_0-rmse:1.01344	validation_1-rmse:1.18605
# [125]	validation_0-rmse:1.01233	validation_1-rmse:1.18596
# [126]	validation_0-rmse:1.01139	validation_1-rmse:1.18592
# [127]	validation_0-rmse:1.01106	validation_1-rmse:1.18602
# [128]	validation_0-rmse:1.01071	validation_1-rmse:1.18583
# [129]	validation_0-rmse:1.00999	validation_1-rmse:1.18554
# [130]	validation_0-rmse:1.00959	validation_1-rmse:1.18548
# [131]	validation_0-rmse:1.00954	validation_1-rmse:1.1855
# [132]	validation_0-rmse:1.0089	validation_1-rmse:1.18508
# [133]	validation_0-rmse:1.00829	validation_1-rmse:1.18503
# [134]	validation_0-rmse:1.00787	validation_1-rmse:1.18499
# [135]	validation_0-rmse:1.00713	validation_1-rmse:1.18498
# [136]	validation_0-rmse:1.00633	validation_1-rmse:1.18493
# [137]	validation_0-rmse:1.00613	validation_1-rmse:1.1849
# [138]	validation_0-rmse:1.00588	validation_1-rmse:1.18473
# [139]	validation_0-rmse:1.00533	validation_1-rmse:1.18468
# [140]	validation_0-rmse:1.00454	validation_1-rmse:1.18461
# [141]	validation_0-rmse:1.00375	validation_1-rmse:1.18449
# [142]	validation_0-rmse:1.00322	validation_1-rmse:1.18419
# [143]	validation_0-rmse:1.00245	validation_1-rmse:1.18388
# [144]	validation_0-rmse:1.00176	validation_1-rmse:1.18372
# [145]	validation_0-rmse:1.00074	validation_1-rmse:1.1833
# [146]	validation_0-rmse:1.00022	validation_1-rmse:1.18315
# [147]	validation_0-rmse:0.999654	validation_1-rmse:1.18311
# [148]	validation_0-rmse:0.999215	validation_1-rmse:1.18282
# [149]	validation_0-rmse:0.998297	validation_1-rmse:1.18292
# [150]	validation_0-rmse:0.998128	validation_1-rmse:1.18296
# [151]	validation_0-rmse:0.997528	validation_1-rmse:1.18314
# [152]	validation_0-rmse:0.997305	validation_1-rmse:1.18318
# [153]	validation_0-rmse:0.996922	validation_1-rmse:1.18328
# [154]	validation_0-rmse:0.996121	validation_1-rmse:1.18325
# [155]	validation_0-rmse:0.995651	validation_1-rmse:1.18312
# [156]	validation_0-rmse:0.995449	validation_1-rmse:1.18314
# [157]	validation_0-rmse:0.995263	validation_1-rmse:1.18326
# [158]	validation_0-rmse:0.994715	validation_1-rmse:1.18316
# Stopping. Best iteration:
# [148]	validation_0-rmse:0.999215	validation_1-rmse:1.18282
#
# Total of training time:  444.67452216148376

# %%
y_pred = model.predict(X_test)
print('RMSE: ', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# RMSE:  1.2043484886867997

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

#fig, ax = plt.subplots(1,1,figsize=(10,10))
plot_importance(model, max_num_features=25, grid=False, height=0.5, importance_type='weight')

# %%
from sklearn.neural_network import MLPRegressor


model = MLPRegressor(hidden_layer_sizes=(128, 64, 64,32), learning_rate_init=0.01, verbose=True, max_iter=200)
concat_X_train = X_train.append(X_valid)
concat_y_train = y_train.append(y_valid)
model.fit(X_train.values, y_train.values)
y_pred = model.predict(X_test.values)
print('RMSE Neural Network: ', np.sqrt(mean_squared_error(y_test.values, y_pred)))
# Out:
# Iteration 1, loss = 2.10401754
# Iteration 2, loss = 0.75364333
# Iteration 3, loss = 0.73856529
# Iteration 4, loss = 0.75317546
# Iteration 5, loss = 0.74093112
# Iteration 6, loss = 0.75202527
# Iteration 7, loss = 0.72824700
# Iteration 8, loss = 0.72429117
# Iteration 9, loss = 0.72332882
# Iteration 10, loss = 0.72248244
# Iteration 11, loss = 0.74999892
# Iteration 12, loss = 0.70849271
# Iteration 13, loss = 0.70451918
# Iteration 14, loss = 0.85993663
# Iteration 15, loss = 0.82714596
# Iteration 16, loss = 0.75866667
# Iteration 17, loss = 0.73915209
# Iteration 18, loss = 0.73282841
# Iteration 19, loss = 0.72345145
# Iteration 20, loss = 0.71719373
# Iteration 21, loss = 0.71542648
# Iteration 22, loss = 0.71529383
# Iteration 23, loss = 0.71273339
# Iteration 24, loss = 0.70713056
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# RMSE Neural Network:  1.243100416513755
